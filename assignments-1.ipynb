# %% [markdown]
# #### Assignment Set 1 by Pegah Khazaei for Applied Machine Learning (Spring 2020) Course at Data Science Center, SBU

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import sklearn

# %%
start_time = time.time()
data = {'a': np.arange(500),
        'c': np.random.randint(0, 500, 500),
        'd': np.random.randn(500)}
data['b'] = data['a'] + 10 * np.random.randn(500)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()
df = pd.DataFrame(np.random.randn(10, 4)) 
print(df)

j=1.23
for i in range(80000000):
  j+=j    

print("\n-> Execution Time = %s in Seconds <-" % (time.time() - start_time))
# Out:
#           0         1         2         3
# 0  1.286423 -0.640973  0.116010 -1.208977
# 1 -0.348292 -0.495239  1.215509 -0.274603
# 2 -0.187541 -0.154444  2.000901  0.519111
# 3 -0.236701 -2.095179  0.199630 -0.966094
# 4 -1.083976 -1.579950  1.032777 -0.994568
# 5  0.066589 -0.134967 -1.136233  0.638505
# 6  1.468592 -0.534302  0.268685  0.735812
# 7 -1.528894  0.517003  1.475161 -0.388034
# 8 -0.578573 -0.532280 -2.008105 -0.534557
# 9 -0.449502  0.676425  1.339962 -0.634808
#
# -> Execution Time = 16.977852821350098 in Seconds <-
